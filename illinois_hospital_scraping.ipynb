# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Create an URL object
url = 'https://www.ahd.com/states/hospital_IL.html'
r = requests.get(url)

#check status/response 
# print(r.status_code)

# soup = BeautifulSoup(r.text, 'html.parser')
# parser-lxml = Change html to Python friendly format
soup = BeautifulSoup(r.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en-US">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    American Hospital Directory - Abuse
#   </title>
#   <meta content="The American Hospital Directory provides operational data, financial information, utilization statistics and other benchmarks for acute care hospitals." name="description"/>
#   <meta content="hospital, hospitals, hospital data, hospital performance, health care,  quality outcomes, clinical quality measurements, HCFA, CMS, MedPAR, HEDIS, AMA, NCQA, JCAHO, HFMA, DRG, information, statistics, benchmark, benchmarks, benchmarking" name="keywords"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <base href="https://www.ahd.com/" id="myBaseId"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/touch-icon-iphone.png" rel="apple-touch-icon"/>
#   <link href="/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/styles/ahd2010.72.css" rel="stylesheet" type="text/css"/>
#   <link href="/styles/jquery.fancybox-2.1.5.css?v=72" rel="stylesheet" type="text/css"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js">
#   </script>
#   <script src="/core/js/autosuggest.js?33" type="text/javascript">
#   </script>
#   <script src="/js/jquery.ba-resize.min.js" type="text/javascript">
#   </script>
#   <script src="/js/jquery.fancybox-2.1.5.pack.js" type="text/javascript">
#   </script>
#   <script src="/js/jScrollTouch.js" type="text/javascript">
#   </script>
#   <script src="/js/ahd_tools.44.js" type="text/javascript">
#   </script>
#  </head>
#  <body id="body" topmargin="0">
#   <div id="wrapper">
#    <div id="main_content">
#     <div id="header">
#      <div id="logo">
#       <a href="/">
#        <span class="sprite ahdlogo_220">
#        </span>
#       </a>
#      </div>
#      <div id="navigation_bar">
#       <div id="nav_left">
#       </div>
#       <div id="nav_wrap">
#        <div class="nav_row" style="text-align: right;">
#         <ul id="topnav">
#         </ul>
#        </div>
#        <form action="/states/hospital_IL.html" method="post" name="NAVLOGINFORM">
#         <div id="loginform">
#          <input id="LES" name="LES" type="hidden" value="1656183815"/>
#          <div style="text-align: right;">
#           <div>
#            <label for="LOGIN_UNAME">
#             User Name:
#            </label>
#            <input accesskey="u" id="LOGIN_UNAME" name="LOGIN_UNAME" size="12" spellcheck="false" type="text"/>
#           </div>
#           <div>
#            <label for="LOGIN_PWD">
#             Password:
#            </label>
#            <input id="LOGIN_PWD" name="LOGIN_PWD" size="12" type="password"/>
#           </div>
#          </div>
#         </div>
#         <div class="nav_row">
#          <div class="nav_spacer">
#          </div>
#          <div class="navbuttons">
#           <a href="/">
#            Home
#           </a>
#          </div>
#          <div class="navbuttons">
#           <a href="/search.php">
#            FREE Search
#           </a>
#          </div>
#          <div class="navbuttons">
#           <a href="/faq.html" title="Answers to Frequently Asked Questions">
#            FAQs
#           </a>
#          </div>
#          <div class="navbuttons">
#           <a href="/data_sources.html" title="Current Data Sources">
#            Sources
#           </a>
#          </div>
#          <div class="navbuttons">
#           <a href="/enhancements.html" title="Recent Enhancements">
#            Updates
#           </a>
#          </div>
#          <div class="navbuttons_ordernow">
#           <a href="/ordernow.html">
#            Order Info
#           </a>
#          </div>
#          <div class="nav_open_spacer">
#          </div>
#          <div class="navbuttons">
#           <input id="login" type="submit" value="Login"/>
#          </div>
#          <div class="nav_spacer">
#          </div>
#         </div>
#        </form>
#       </div>
#       <div id="nav_right">
#       </div>
#      </div>
#      <div style="clear: both; height: 0px;">
#      </div>
#     </div>
#     <div id="main">
#      <div id="rpt_header">
#       <div>
#       </div>
#       <div>
#        <h2 id="page_title">
#         Abuse
#        </h2>
#       </div>
#      </div>
#      <div class="subcontent">
#       <p>
#        Your access to AHD.com has been suspended for suspected abuse of our terms and conditions of use.
#       </p>
#       <p>
#        The use of an automated process (which is prohibited under our terms of service) or high volumes of usage from one location are common causes for this to occur.
#       </p>
#       <p>
#        To be considered for reinstatement, please contact
#        <a href="mailto:support@ahd.com">
#         support@ahd.com
#        </a>
#        with your IP address (73.8.91.151), the time and date you first received this message, and any explanation you have regarding irregular usage of AHD.com at the time of suspension.
#       </p>
#      </div>
#      <div align="center" id="footer">
#       <table cellpadding="0" cellspacing="0" width="820">
#        <tr>
#         <td align="left" width="100%">
#          <hr color="#D6D6D6" size="1"/>
#          <a href="/">
#           <div class="sprite ahdlogoBW_180">
#           </div>
#          </a>
#          <a href="/about.html">
#           About the company
#          </a>
#          |
#          <a href="/sitemap.html">
#           Site Map
#          </a>
#          |
#                                 Email:
#          <a href="mailto:support@ahd.com">
#           support@ahd.com
#          </a>
#          |
#          <a class="popup" href="/policy_privacy.html">
#           Privacy Policy
#          </a>
#          |
#          <a href="/media/">
#           Media
#          </a>
#          <br/>
#          Users should read
#          <a href="/agree.html">
#           notice, disclaimer, and agreement
#          </a>
#          |
#          <br/>
#          Copyright ©2000-2022 American Hospital Directory, Inc. All rights reserved.
#         </td>
#        </tr>
#       </table>
#      </div>
#     </div>
#    </div>
#    <div id="main_container">
#    </div>
#    <div id="left_outer">
#    </div>
#    <div id="left_inner">
#    </div>
#    <div id="right_outer">
#    </div>
#    <div id="right_inner">
#    </div>
#   </div>
#   <script type="text/javascript">
#    $(document).ready(function () { ahd_init_popup_links();
#     $('.help_ajax').fancybox({
#         scrolling: 'none',
#         type: 'ajax',
#         margin: 10,
#         width: 650,
#         onstart: function() { },
#         titleFormat: function() {
#             var alt_name = $(this.orig).parent().attr('alt');
#             if(alt_name != undefined) {
#                 return "<table id='fancybox-title-float-wrap'><tbody><tr><td id='fancybox-title-float-left' style='padding-left: 10px;'>&nbsp;</td><td id='fancybox-title-float-main'>" + alt_name + "</td><td id='fancybox-title-float-right'>&nbsp;</td></tr></tbody></table>";
#             } else {
#                 return '';
#             }
#         }
#         }); });
#   </script>
#   <!-- -->
#  </body>
# </html>

# %%
# Obtain information from tag <table>
hospital_table = soup.find('table')
hospital_table
# Out:
# <table cellpadding="0" cellspacing="0" width="820">
# <tr>
# <td align="left" width="100%">
# <hr color="#D6D6D6" size="1"/>
# <a href="/"><div class="sprite ahdlogoBW_180"></div></a>
# <a href="/about.html">About the company</a>
#                                  |
#                                 <a href="/sitemap.html">Site Map</a>
#                                  |
#                                 Email:
#                                 <a href="mailto:support@ahd.com">support@ahd.com</a>
#                                  |
#                                 <a class="popup" href="/policy_privacy.html">Privacy Policy</a>
#                                  |
#                                 <a href="/media/">Media</a>
# <br/>
#                                 Users should read
#                                 <a href="/agree.html">notice, disclaimer, and agreement</a>
#                                  | <br/>
#                                 Copyright ©2000-2022 American Hospital Directory, Inc. All rights reserved.
#                             </td>
# </tr>
# </table>

# %%
# Obtain every title of columns with tag <th>
headers = []
for i in hospital_table.find_all('th'):
 title = i.text
 headers.append(title)
headers
# Out:
# []

# %%
# Create a dataframe
hospital_data = pd.DataFrame(columns = headers)
hospital_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create a for loop to fill mydata
for j in hospital_table.find_all('tr')[1:]:
 row_data = j.find_all('td')
 row = [i.text for i in row_data]
 length = len(hospital_data)
 hospital_data.loc[length] = row
hospital_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
hospital_data['StaffedBeds'] = hospital_data['StaffedBeds'].str.replace(',', '')
hospital_data['TotalDischarges'] = hospital_data['TotalDischarges'].str.replace(',', '')
hospital_data['PatientDays'] = hospital_data['PatientDays'].str.replace(',', '')
hospital_data['Gross PatientRevenue ($000)'] = hospital_data['Gross PatientRevenue ($000)'].str.replace(',', '')
hospital_data['Gross PatientRevenue ($000)'] = hospital_data['Gross PatientRevenue ($000)'].str.replace('$', '')
hospital_data['StaffedBeds'] = hospital_data['StaffedBeds'].astype(int)
hospital_data['TotalDischarges'] = hospital_data['TotalDischarges'].astype(int)
hospital_data['PatientDays'] = hospital_data['PatientDays'].astype(int)
hospital_data['Gross PatientRevenue ($000)'] = hospital_data['Gross PatientRevenue ($000)'].astype(int)
hospital_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'StaffedBeds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32720/3146634790.py in <module>
# ----> 1 hospital_data['StaffedBeds'] = hospital_data['StaffedBeds'].str.replace(',', '')
#       2 hospital_data['TotalDischarges'] = hospital_data['TotalDischarges'].str.replace(',', '')
#       3 hospital_data['PatientDays'] = hospital_data['PatientDays'].str.replace(',', '')
#       4 hospital_data['Gross PatientRevenue ($000)'] = hospital_data['Gross PatientRevenue ($000)'].str.replace(',', '')
#       5 hospital_data['Gross PatientRevenue ($000)'] = hospital_data['Gross PatientRevenue ($000)'].str.replace('$', '')
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'StaffedBeds'

# %%
hospital_data_clean = hospital_data[hospital_data['StaffedBeds']>0]
hospital_data_clean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'StaffedBeds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32720/2661178093.py in <module>
# ----> 1 hospital_data_clean = hospital_data[hospital_data['StaffedBeds']>0]
#       2 hospital_data_clean
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\ameli\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'StaffedBeds'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5652/402530072.py in <module>
# ----> 1 google_reviewspt3.csv.pd.read_csv()
#
# NameError: name 'google_reviewspt3' is not defined

# %%
reviews = 'google_reviewspt3.csv'
reviews_db = pd.read_csv(reviews)
reviews_db.head()
# Out:
#                                hospital_name  google_stars  Unnamed: 2  \
# 0           Carle Richland Memorial Hospital           3.1         NaN
# 1  Northwestern Medicine Kishwaukee Hospital           2.4         NaN
# 2                   AdventHealth Bolingbrook           2.5         NaN
# 3                      AdventHealth GlenOaks           2.7         NaN
# 4                      AdventHealth Hinsdale           3.2         NaN
#
#    Unnamed: 3  Unnamed: 4
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
